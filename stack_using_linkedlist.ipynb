# %%
class StackNode:
  def __init__(self, NewData,link):
    self.data=NewData
    self.next=link
class Stack:
  def __init__(self):
    self.top=None
  def isempty(self):
    return self.top is None
  def peek(self):
    return self.top.data
  def pop(self):
    node=self.top
    self.top=self.top.next
    return node.data
  def push(self,NewData):
    self.top=StackNode(NewData,self.top)
  def display(self):
    curNode=self.top
    print()
    while curNode is not None:
      print(curNode.data)
      curNode=curNode.next

s=Stack()
while(True):
  print("Program to implement stack")
  print("1.push")
  print("2.pop")
  print("3.peek")
  print("4.Display")
  print("5.Exit")
  choice=int(input("Enter your choice:"))
  if choice==1:
    num=int(input("Enter the data:"))
    s.push(num)
  elif choice==2:
    if s.isempty():
      print("Stack underflow!!!")
    else:
      num=s.pop()
      print("popped data:",num)
  elif choice==3:
    if s.isempty():
      print("Stack underflow!!!")
    else:
      num=s.peek()
      print("Data at the top of stack:",num)
  elif choice==4:
    if s.isempty():
      print("Stack is empty!!!")
    else:
      s.display()
  elif choice==5:
    print("\n Quitting...")
    break
  else:
    print("Invalid choice. Enter the correct choice(1-5)")
    continue
# Out:
# Program to implement stack
# 1.push
# 2.pop
# 3.peek
# 4.Display
# 5.Exit
# Enter your choice:1
# Enter the data:10
# Program to implement stack
# 1.push
# 2.pop
# 3.peek
# 4.Display
# 5.Exit
# Enter your choice:2
# popped data: 10
# Program to implement stack
# 1.push
# 2.pop
# 3.peek
# 4.Display
# 5.Exit
# Enter your choice:1
# Enter the data:20
# Program to implement stack
# 1.push
# 2.pop
# 3.peek
# 4.Display
# 5.Exit
# Enter your choice:1
# Enter the data:30
# Program to implement stack
# 1.push
# 2.pop
# 3.peek
# 4.Display
# 5.Exit
# Enter your choice:4
#
# 30
# 20
# Program to implement stack
# 1.push
# 2.pop
# 3.peek
# 4.Display
# 5.Exit
# Enter your choice:1
# Enter the data:50
# Program to implement stack
# 1.push
# 2.pop
# 3.peek
# 4.Display
# 5.Exit
# Enter your choice:1
# Enter the data:90
# Program to implement stack
# 1.push
# 2.pop
# 3.peek
# 4.Display
# 5.Exit
# Enter your choice:4
#
# 90
# 50
# 30
# 20
# Program to implement stack
# 1.push
# 2.pop
# 3.peek
# 4.Display
# 5.Exit
# Enter your choice:5
#
#  Quitting...
